# %%
# !pip install yfinance

# %%
# dependencies
import yfinance as yf
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String, Date, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
from datetime import date

# %%
# session stuff
session = Session(engine)
Base = declarative_base()

# %%
# Creates a connection to our DB. if file doesn't exist, we create it
# echo=True is verbose
engine = create_engine("sqlite:///stocks.sqlite", echo=True)
conn = engine.connect()


# # Define our pet table
# probably deprecated after i found out about df.to_sql method
# class stock(Base):
#     __tablename__ = 'stock'
#     id = Column(Integer, primary_key=True)
#     name = Column(String)
#     type = Column(String)
#     date = Column(Date)
# # creates table
# Base.metadata.create_all(engine)

# %%
# choose tickers here
tickerStrings = ['AAPL', 'MSFT']

# %%
# yfinance code to separate tickers into pretty dataframe
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, group_by="Ticker", period='2d')
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
tickerDf = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tickerDf.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-06-28  142.130005  143.419998  137.320007  137.440002  137.440002
# 2022-06-29  137.460007  140.669998  136.669998  139.229996  139.229996
# 2022-06-28  263.980011  266.910004  256.320007  256.480011  256.480011
# 2022-06-29  257.589996  261.970001  255.759995  260.260010  260.260010
#
#               Volume ticker
# Date
# 2022-06-28  67083400   AAPL
# 2022-06-29  65894585   AAPL
# 2022-06-28  27295500   MSFT
# 2022-06-29  19990083   MSFT

# %%
# this will push dataframe to sql, creating a table if none exists
tickerDf.to_sql('stocks', conn, if_exists='append')
# Out:
# 2022-06-29 19:40:05,051 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("stocks")
# 2022-06-29 19:40:05,053 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-29 19:40:05,058 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-29 19:40:05,062 INFO sqlalchemy.engine.Engine INSERT INTO stocks ("Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", ticker) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2022-06-29 19:40:05,064 INFO sqlalchemy.engine.Engine [generated in 0.00240s] (('2022-06-28 00:00:00.000000', 142.1300048828125, 143.4199981689453, 137.32000732421875, 137.44000244140625, 137.44000244140625, 67083400, 'AAPL'), ('2022-06-29 00:00:00.000000', 137.4600067138672, 140.6699981689453, 136.6699981689453, 139.22999572753906, 139.22999572753906, 65894585, 'AAPL'), ('2022-06-28 00:00:00.000000', 263.9800109863281, 266.9100036621094, 256.32000732421875, 256.4800109863281, 256.4800109863281, 27295500, 'MSFT'), ('2022-06-29 00:00:00.000000', 257.5899963378906, 261.9700012207031, 255.75999450683594, 260.260009765625, 260.260009765625, 19990083, 'MSFT'))
# 2022-06-29 19:40:05,065 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tickerDf.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-06-28  142.130005  143.419998  137.320007  137.440002  137.440002
# 2022-06-29  137.460007  140.669998  136.669998  139.229996  139.229996
# 2022-06-28  263.980011  266.910004  256.320007  256.480011  256.480011
# 2022-06-29  257.589996  261.970001  255.759995  260.260010  260.260010
#
#               Volume ticker
# Date
# 2022-06-28  67083400   AAPL
# 2022-06-29  65894585   AAPL
# 2022-06-28  27295500   MSFT
# 2022-06-29  19990083   MSFT

# %%
btc = pd.read_csv("data_crypto/bitcoin_2012-1-1_2022-6-27.csv")
btc
# Out:
#             Date          Open          High           Low         Close  \
# 0    Jun-26-2022  21504.605967  21836.737838  21001.378699  21029.216300
# 1    Jun-19-2022  19010.476500  20706.316100  18022.469505  20554.902700
# 2    Jun-12-2022  28415.542200  28519.740800  26704.729357  26704.729357
# 3    Jun-05-2022  29847.326342  30162.096092  29591.635303  29909.210373
# 4    May-29-2022  29031.307367  29530.422915  28855.558900  29445.724100
# ..           ...           ...           ...           ...           ...
# 543  Jan-29-2012      5.380900      5.380900      5.380900      5.380900
# 544  Jan-22-2012      6.309700      6.309700      6.309700      6.309700
# 545  Jan-15-2012      7.001800      7.001800      7.001800      7.001800
# 546  Jan-08-2012      7.113600      7.113600      7.113600      7.113600
# 547  Jan-01-2012      5.267700      5.267700      5.267700      5.267700
#
#            Volume    Market Cap
# 0    3.601759e+10  4.077261e+11
# 1    8.274432e+10  3.680858e+11
# 2    6.030508e+10  5.270696e+11
# 3    2.808424e+10  5.682769e+11
# 4    2.908444e+10  5.552257e+11
# ..            ...           ...
# 543  0.000000e+00  0.000000e+00
# 544  0.000000e+00  0.000000e+00
# 545  0.000000e+00  0.000000e+00
# 546  0.000000e+00  0.000000e+00
# 547  0.000000e+00  0.000000e+00
#
# [548 rows x 7 columns]

# %%
btc["ticker"]='btc'
btc.head()
# Out:
#           Date          Open          High           Low         Close  \
# 0  Jun-26-2022  21504.605967  21836.737838  21001.378699  21029.216300
# 1  Jun-19-2022  19010.476500  20706.316100  18022.469505  20554.902700
# 2  Jun-12-2022  28415.542200  28519.740800  26704.729357  26704.729357
# 3  Jun-05-2022  29847.326342  30162.096092  29591.635303  29909.210373
# 4  May-29-2022  29031.307367  29530.422915  28855.558900  29445.724100
#
#          Volume    Market Cap ticker
# 0  3.601759e+10  4.077261e+11    btc
# 1  8.274432e+10  3.680858e+11    btc
# 2  6.030508e+10  5.270696e+11    btc
# 3  2.808424e+10  5.682769e+11    btc
# 4  2.908444e+10  5.552257e+11    btc

# %%
btc.to_sql('stocks', conn, if_exists='append')
# Out:
# 2022-06-29 19:34:05,063 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("stocks")
# 2022-06-29 19:34:05,064 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-29 19:34:05,070 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-29 19:34:05,084 INFO sqlalchemy.engine.Engine INSERT INTO stocks ("index", "Date", "Open", "High", "Low", "Close", "Volume", "Market Cap", ticker) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-06-29 19:34:05,085 INFO sqlalchemy.engine.Engine [generated in 0.01238s] ((0, 'Jun-26-2022', 21504.60596690371, 21836.73783767194, 21001.37869884742, 21029.2163, 36017590144.0, 407726053064.8783, 'btc'), (1, 'Jun-19-2022', 19010.4765, 20706.3161, 18022.46950501365, 20554.9027, 82744323328.0, 368085789556.554, 'btc'), (2, 'Jun-12-2022', 28415.5422, 28519.7408, 26704.72935717625, 26704.72935717625, 60305080590.22222, 527069614633.2744, 'btc'), (3, 'Jun-05-2022', 29847.32634215065, 30162.09609162581, 29591.635302773604, 29909.210373336216, 28084240917.33333, 568276877179.0026, 'btc'), (4, 'May-29-2022', 29031.307367141795, 29530.42291497669, 28855.5589, 29445.7241, 29084438122.666668, 555225725632.1536, 'btc'), (5, 'May-22-2022', 29445.062122180065, 30426.8779609496, 29246.77654664081, 30366.04222096173, 34792840362.666664, 567574103618.3665, 'btc'), (6, 'May-15-2022', 30076.9329, 31390.4799, 29512.2442, 31333.765617069977, 45280980437.333336, 573617058982.2653, 'btc'), (7, 'May-08-2022', 35478.5649, 35496.13500451754, 33828.1358, 33933.54281002884, 59930329173.333336, 657631808942.3683, 'btc')  ... displaying 10 of 548 total bound parameter sets ...  (546, 'Jan-08-2012', 7.1136, 7.1136, 7.1136, 7.1136, 0.0, 0.0, 'btc'), (547, 'Jan-01-2012', 5.2677, 5.2677, 5.2677, 5.2677, 0.0, 0.0, 'btc'))
# 2022-06-29 19:34:05,086 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     728     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 729         cursor.executemany(statement, parameters)
#     730
#
# OperationalError: table stocks has no column named index
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /var/folders/pr/1_6x41cj4bg9v9n2y7ppnzyc0000gn/T/ipykernel_85308/3325463377.py in <module>
# ----> 1 btc.to_sql('stocks', conn, if_exists='append')
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1768             chunksize=chunksize,
#    1769             method=method,
# -> 1770             **engine_kwargs,
#    1771         )
#    1772
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1293             )
#    1294         else:
# -> 1295             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1296
#    1297     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     324         if _force or self.supports_execution:
#     325             return connection._execute_clauseelement(
# --> 326                 self, multiparams, params, execution_options
#     327             )
#     328         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1495             elem,
#    1496             extracted_params,
# -> 1497             cache_hit=cache_hit,
#    1498         )
#    1499         if has_events:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1850         except BaseException as e:
#    1851             self._handle_dbapi_exception(
# -> 1852                 e, statement, parameters, cursor, context
#    1853             )
#    1854
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2031             elif should_wrap:
#    2032                 util.raise_(
# -> 2033                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034                 )
#    2035             else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787                 if not evt_handled:
#    1788                     self.dialect.do_executemany(
# -> 1789                         cursor, statement, parameters, context
#    1790                     )
#    1791             elif not parameters and context.no_parameters:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     727
#     728     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 729         cursor.executemany(statement, parameters)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
#
# OperationalError: (sqlite3.OperationalError) table stocks has no column named index
# [SQL: INSERT INTO stocks ("index", "Date", "Open", "High", "Low", "Close", "Volume", "Market Cap", ticker) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ((0, 'Jun-26-2022', 21504.60596690371, 21836.73783767194, 21001.37869884742, 21029.2163, 36017590144.0, 407726053064.8783, 'btc'), (1, 'Jun-19-2022', 19010.4765, 20706.3161, 18022.46950501365, 20554.9027, 82744323328.0, 368085789556.554, 'btc'), (2, 'Jun-12-2022', 28415.5422, 28519.7408, 26704.72935717625, 26704.72935717625, 60305080590.22222, 527069614633.2744, 'btc'), (3, 'Jun-05-2022', 29847.32634215065, 30162.09609162581, 29591.635302773604, 29909.210373336216, 28084240917.33333, 568276877179.0026, 'btc'), (4, 'May-29-2022', 29031.307367141795, 29530.42291497669, 28855.5589, 29445.7241, 29084438122.666668, 555225725632.1536, 'btc'), (5, 'May-22-2022', 29445.062122180065, 30426.8779609496, 29246.77654664081, 30366.04222096173, 34792840362.666664, 567574103618.3665, 'btc'), (6, 'May-15-2022', 30076.9329, 31390.4799, 29512.2442, 31333.765617069977, 45280980437.333336, 573617058982.2653, 'btc'), (7, 'May-08-2022', 35478.5649, 35496.13500451754, 33828.1358, 33933.54281002884, 59930329173.333336, 657631808942.3683, 'btc')  ... displaying 10 of 548 total bound parameter sets ...  (546, 'Jan-08-2012', 7.1136, 7.1136, 7.1136, 7.1136, 0.0, 0.0, 'btc'), (547, 'Jan-01-2012', 5.2677, 5.2677, 5.2677, 5.2677, 0.0, 0.0, 'btc'))]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
